# %% [markdown]
# <a href="https://colab.research.google.com/github/zaid-builds/learning-repo/blob/main/examples/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png">
#   </a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/models/ultralytics/yolo26"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
# </div>
#
# This **Ultralytics Colab Notebook** is the easiest way to get started with [YOLO models](https://www.ultralytics.com/yolo)—no installation needed. Built by [Ultralytics](https://www.ultralytics.com/), the creators of YOLO, this notebook walks you through running **state-of-the-art** models directly in your browser.
#
# Ultralytics models are constantly updated for performance and flexibility. They're **fast**, **accurate**, and **easy to use**, and they excel at [object detection](https://docs.ultralytics.com/tasks/detect/), [tracking](https://docs.ultralytics.com/modes/track/), [instance segmentation](https://docs.ultralytics.com/tasks/segment/), [image classification](https://docs.ultralytics.com/tasks/classify/), and [pose estimation](https://docs.ultralytics.com/tasks/pose/).
#
# Find detailed documentation in the [Ultralytics Docs](https://docs.ultralytics.com/). Get support via [GitHub Issues](https://github.com/ultralytics/ultralytics/issues/new/choose). Join discussions on [Discord](https://discord.com/invite/ultralytics), [Reddit](https://www.reddit.com/r/ultralytics/), and the [Ultralytics Community Forums](https://community.ultralytics.com/)!
#
# Request an Enterprise License for commercial use at [Ultralytics Licensing](https://www.ultralytics.com/license).

# %% [markdown]
# # Setup
#
# pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.7/112.6 GB disk)

# %% [markdown]
# # 1. Predict
#
# YOLO26 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO26 Predict Docs](https://docs.ultralytics.com/modes/predict/).

# %%
# Run inference on an image with YOLO26n
# !yolo predict model=yolo26n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 293.5MB/s 0.0s
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# Downloading https://ultralytics.com/images/zidane.jpg to 'zidane.jpg': 100% ━━━━━━━━━━━━ 49.2KB 42.2MB/s 0.0s
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 56.0ms
# Speed: 11.6ms preprocess, 56.0ms inference, 36.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/212889447-69e5bdf1-5800-4e29-835e-2ed2336dede2.jpg" width="600">

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://docs.ultralytics.com/datasets/detect/coco/) dataset's `val` or `test` splits. The latest YOLO26 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLO26 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Download COCO val
from ultralytics.utils.downloads import download

download('https://ultralytics.com/assets/coco2017val.zip', unzip=True, dir='datasets') # download (780MB - 5000 images)

# %%
# Validate YOLO26n on COCO8 val
# !yolo val model=yolo26n.pt data=coco8.yaml
# Out:
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/content/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/content/datasets/coco8.zip': 100% ━━━━━━━━━━━━ 432.8KB 36.5MB/s 0.0s
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 5.1Kfiles/s 0.0s
# Dataset download success ✅ (0.7s), saved to /content/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 106.1MB/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1236.6±358.3 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 103.0it/s 0.0s
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all          4         17      0.849      0.654      0.907      0.667
#                 person          3         10          1      0.427      0.766      0.378
#                    dog          1          1      0.718          1      0.995      0.597
#                  horse          1          2        0.8          1      0.995      0.798
#               elephant          1          2      0.854        0.5      0.695      0.438
#               umbrella          1          1      0.724          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 1.0ms preprocess, 16.3ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /content/runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://ultralytics.com/hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLO26 on [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/) datasets. See [YOLO26 Train Docs](https://docs.ultralytics.com/modes/train/) for more information.

# %%
#@title Select YOLO26 🚀 logger {run: 'auto'}
logger = 'TensorBoard' #@param ['TensorBoard', 'Weights & Biases']

if logger == 'TensorBoard':
  # !yolo settings tensorboard=True
  # %load_ext tensorboard
  # %tensorboard --logdir .
elif logger == 'Weights & Biases':
  # !yolo settings wandb=True

# %%
# !unzip digioptics-dataset-v1.zip -d /content/
# Out:
# Archive:  digioptics-dataset-v1.zip
#    creating: /content/digioptics-dataset-v1/
#   inflating: /content/digioptics-dataset-v1/data.yaml
#    creating: /content/digioptics-dataset-v1/train/
#    creating: /content/digioptics-dataset-v1/train/images/
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi1.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi10.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi3.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi4.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi5.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi551.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi552.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi553.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi554.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi555.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi556.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi557.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi559.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi560.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi573.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi574.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi575.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi576.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi577.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi579.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi580.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi581.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi582.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi585.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi586.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi587.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi588.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi589.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi590.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi591.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi593.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi594.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi6.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi7.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi8.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/bisturi9.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca1.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca2.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca4.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca461.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca463.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca464.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca465.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca468.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca469.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca470.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca473.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca474.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca475.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca477.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca478.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca480.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca482.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca490.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca491.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca493.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca494.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca495.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca496.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca497.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca498.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca499.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca5.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca6.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca7.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/pinca9.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/separado100.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/separado92.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/separado94.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/separado95.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/separado96.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/separado98.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/separado99.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva1.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva10.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva2.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva4.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva5.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva551.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva552.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva553.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva555.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva556.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva557.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva558.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva559.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva569.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva572.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva573.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva574.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva575.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva576.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva578.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva6.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva632.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva633.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva634.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva636.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva638.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva639.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva640.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva7.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesouracurva8.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta1.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta10.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta2.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta4.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta452.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta453.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta455.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta456.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta457.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta458.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta460.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta472.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta473.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta474.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta475.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta476.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta477.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta478.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta479.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta480.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta481.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta5.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta503.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta504.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta505.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta506.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta507.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta508.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta510.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta6.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta7.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta8.jpg
#   inflating: /content/digioptics-dataset-v1/train/images/tesourareta9.jpg
#    creating: /content/digioptics-dataset-v1/train/labels/
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi1.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi10.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi3.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi4.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi5.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi551.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi552.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi553.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi554.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi555.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi556.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi557.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi559.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi560.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi573.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi574.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi575.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi576.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi577.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi579.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi580.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi581.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi582.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi585.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi586.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi587.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi588.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi589.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi590.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi591.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi593.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi594.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi6.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi7.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi8.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/bisturi9.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca1.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca2.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca4.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca461.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca463.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca464.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca465.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca468.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca469.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca470.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca473.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca474.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca475.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca477.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca478.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca480.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca482.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca490.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca491.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca493.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca494.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca495.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca496.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca497.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca498.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca499.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca5.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca6.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca7.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/pinca9.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/separado100.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/separado92.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/separado94.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/separado95.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/separado96.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/separado98.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/separado99.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva1.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva10.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva2.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva4.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva5.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva551.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva552.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva553.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva555.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva556.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva557.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva558.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva559.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva569.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva572.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva573.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva574.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva575.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva576.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva578.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva6.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva632.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva633.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva634.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva636.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva638.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva639.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva640.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva7.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesouracurva8.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta1.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta10.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta2.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta4.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta452.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta453.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta455.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta456.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta457.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta458.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta460.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta472.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta473.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta474.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta475.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta476.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta477.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta478.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta479.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta480.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta481.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta5.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta503.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta504.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta505.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta506.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta507.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta508.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta510.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta6.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta7.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta8.txt
#   inflating: /content/digioptics-dataset-v1/train/labels/tesourareta9.txt
#    creating: /content/digioptics-dataset-v1/val/
#    creating: /content/digioptics-dataset-v1/val/images/
#   inflating: /content/digioptics-dataset-v1/val/images/bisturi2.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/bisturi558.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/bisturi578.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/bisturi592.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca10.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca3.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca462.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca466.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca467.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca476.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca479.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca481.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca492.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/pinca8.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/separado91.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/separado93.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/separado97.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva3.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva554.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva560.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva570.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva571.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva577.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva631.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva635.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva637.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesouracurva9.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesourareta3.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesourareta451.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesourareta454.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesourareta459.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesourareta501.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesourareta502.jpg
#   inflating: /content/digioptics-dataset-v1/val/images/tesourareta509.jpg
#    creating: /content/digioptics-dataset-v1/val/labels/
#   inflating: /content/digioptics-dataset-v1/val/labels/bisturi2.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/bisturi558.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/bisturi578.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/bisturi592.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca10.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca3.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca462.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca466.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca467.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca476.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca479.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca481.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca492.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/pinca8.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/separado91.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/separado93.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/separado97.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva3.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva554.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva560.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva570.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva571.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva577.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva631.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva635.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva637.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesouracurva9.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesourareta3.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesourareta451.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesourareta454.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesourareta459.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesourareta501.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesourareta502.txt
#   inflating: /content/digioptics-dataset-v1/val/labels/tesourareta509.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Train YOLO26n on COCO8 for 3 epochs
# !yolo train model=yolo26n-seg.pt data=coco8.yaml epochs=500 imgsz=640 batch=64 save_dir=  device=0 exist_ok=True task=segment
# Out:
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=3, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    309656  ultralytics.nn.modules.head.Detect           [80, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,572,280 parameters, 2,572,280 gradients, 6.1 GFLOPs
#
# Transferred 708/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1628.3±611.0 MB/s, size: 50.0 KB)
# train: Scanning /content/datasets/coco8/labels/train... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1.8Kit/s 0.0s
# train: New cache created: /content/datasets/coco8/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.1 ms, read: 439.1±56.8 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 151.1Kit/s 0.0s
# Plotting labels to /content/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.000119, momentum=0.9) with parameter groups 0 weight(decay=0.0), 0 weight(decay=0.0005), 24 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3      0.75G     0.8467       1.76    0.01101         29        640: 100% ━━━━━━━━━━━━ 1/1 11.5s/it 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2s/it 3.2s
#                    all          4         17        0.9      0.653      0.901      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3     0.779G      1.332      2.559    0.01988         46        640: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          4         17      0.895      0.655      0.902      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3     0.805G     0.9497       2.61    0.01205         20        640: 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.4it/s 0.1s
#                    all          4         17      0.874       0.66      0.904      0.667
#
# 3 epochs completed in 0.005 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 5.5MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.9it/s 0.0s
#                    all          4         17        0.9      0.653      0.901      0.668
#                 person          3         10          1       0.42      0.766      0.385
#                    dog          1          1      0.745          1      0.995      0.597
#                  horse          1          2      0.818          1      0.995      0.798
#               elephant          1          2       0.84        0.5      0.662      0.434
#               umbrella          1          1          1          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 0.3ms preprocess, 4.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /content/runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # 4. Export
#
# Export a YOLO model to any supported format below with the `format` argument, i.e. `format=onnx`. See [Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# - 💡 ProTip: Export to [ONNX](https://docs.ultralytics.com/integrations/onnx/) or [OpenVINO](https://docs.ultralytics.com/integrations/openvino/) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://docs.ultralytics.com/integrations/tensorrt/) for up to 5x GPU speedup.
#
# | Format | `format` Argument | Model | Metadata | Arguments |
# |--------|-----------------|-------|----------|------------|
# | [PyTorch](https://pytorch.org/) | - | `yolo26n.pt` | ✅ | - |
# | [TorchScript](https://docs.ultralytics.com/integrations/torchscript) | `torchscript` | `yolo26n.torchscript` | ✅ | `imgsz`, `batch`, `dynamic`, `optimize`, `half`, `nms`, `device` |
# | [ONNX](https://docs.ultralytics.com/integrations/onnx) | `onnx` | `yolo26n.onnx` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `opset`, `simplify`, `nms`, `device` |
# | [OpenVINO](https://docs.ultralytics.com/integrations/openvino) | `openvino` | `yolo26n_openvino_model/` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `int8`, `nms`, `fraction`, `device`, `data` |
# | [TensorRT](https://docs.ultralytics.com/integrations/tensorrt) | `engine` | `yolo26n.engine` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `int8`, `simplify`, `nms`, `fraction`, `device`, `data`, `workspace` |
# | [CoreML](https://docs.ultralytics.com/integrations/coreml) | `coreml` | `yolo26n.mlpackage` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `device` |
# | [TF SavedModel](https://docs.ultralytics.com/integrations/tf-savedmodel) | `saved_model` | `yolo26n_saved_model/` | ✅ | `imgsz`, `batch`, `int8`, `keras`, `nms`, `device` |
# | [TF GraphDef](https://docs.ultralytics.com/integrations/tf-graphdef) | `pb` | `yolo26n.pb` | ❌ | `imgsz`, `batch`, `device` |
# | [TF Lite](https://docs.ultralytics.com/integrations/tflite) | `tflite` | `yolo26n.tflite` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `fraction`, `device`, `data` |
# | [TF Edge TPU](https://docs.ultralytics.com/integrations/edge-tpu) | `edgetpu` | `yolo26n_edgetpu.tflite` | ✅ | `imgsz`, `device` |
# | [TF.js](https://docs.ultralytics.com/integrations/tfjs) | `tfjs` | `yolo26n_web_model/` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `device` |
# | [PaddlePaddle](https://docs.ultralytics.com/integrations/paddlepaddle) | `paddle` | `yolo26n_paddle_model/` | ✅ | `imgsz`, `batch`, `device` |
# | [MNN](https://docs.ultralytics.com/integrations/mnn) | `mnn` | `yolo26n.mnn` | ✅ | `imgsz`, `batch`, `half`, `int8`, `device` |
# | [NCNN](https://docs.ultralytics.com/integrations/ncnn) | `ncnn` | `yolo26n_ncnn_model/` | ✅ | `imgsz`, `batch`, `half`, `device` |
# | [IMX500](https://docs.ultralytics.com/integrations/sony-imx500) | `imx` | `yolo26n_imx_model/` | ✅ | `imgsz`, `int8`, `fraction`, `device`, `data` |
# | [RKNN](https://docs.ultralytics.com/integrations/rockchip-rknn) | `rknn` | `yolo26n_rknn_model/` | ✅ | `imgsz`, `batch`, `name`, `device` |
# | [ExecuTorch](https://docs.ultralytics.com/integrations/executorch) | `executorch` | `yolo26n_executorch_model/` | ✅ | `imgsz`, `device` |
# | [Axelera AI](https://docs.ultralytics.com/integrations/axelera) | `axelera` | `yolo26n_axelera_model/` | ✅ | `imgsz`, `int8`, `fraction`, `device`, `data` |

# %%
# !yolo export model=yolo26n.pt format=torchscript
# Out:
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# PyTorch: starting from 'yolo26n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.3 MB)
#
# TorchScript: starting export with torch 2.9.0+cu126...
# TorchScript: export success ✅ 2.4s, saved as 'yolo26n.torchscript' (9.8 MB)
#
# Export complete (2.9s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolo26n.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolo26n.torchscript imgsz=640 data=/home/lq/codes/ultralytics/ultralytics/cfg/datasets/coco.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# # 5. Python Usage
#
# YOLO26 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLO26 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See detailed Python usage examples in the [YOLO26 Python Docs](https://docs.ultralytics.com/usage/python/).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolo26n.yaml')  # build a new model from scratch
model = YOLO('yolo26n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco8.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results = model.export(format='onnx')  # export the model to ONNX format

# %% [markdown]
# # 6. Tasks
#
# YOLO26 can train, val, predict and export models for the most common tasks in vision AI: [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/). See [YOLO26 Tasks Docs](https://docs.ultralytics.com/tasks/) for more information.
#
# <br><img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/im/banner-tasks.png">

# %% [markdown]
# ## 1. Detection
#
# YOLO26 _detection_ models have no suffix and are the default YOLO26 models, i.e. `yolo26n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %%
# Load YOLO26n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n.pt')  # load a pretrained YOLO detection model
model.train(data='coco8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 2. Segmentation
#
# YOLO26 _segmentation_ models use the `-seg` suffix, i.e. `yolo26n-seg.pt` and are pretrained on COCO. See [Segmentation Docs](https://docs.ultralytics.com/tasks/segment/) for full details.

# %%
# Load YOLO26n-seg, train it on COCO128-seg for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n-seg.pt')  # load a pretrained YOLO segmentation model
model.train(data='coco8-seg.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 3. Classification
#
# YOLO26 _classification_ models use the `-cls` suffix, i.e. `yolo26n-cls.pt` and are pretrained on ImageNet. See [Classification Docs](https://docs.ultralytics.com/tasks/classify/) for full details.

# %%
# Load YOLO26n-cls, train it on mnist160 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n-cls.pt')  # load a pretrained YOLO classification model
model.train(data='mnist160', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Pose
#
# YOLO26 _pose_ models use the `-pose` suffix, i.e. `yolo26n-pose.pt` and are pretrained on COCO Keypoints. See [Pose Docs](https://docs.ultralytics.com/tasks/pose/) for full details.

# %%
# Load YOLO26n-pose, train it on COCO8-pose for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n-pose.pt')  # load a pretrained YOLO pose model
model.train(data='coco8-pose.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 5. Oriented Bounding Boxes (OBB)
#
# YOLO26 _OBB_ models use the `-obb` suffix, i.e. `yolo26n-obb.pt` and are pretrained on the DOTA dataset. See [OBB Docs](https://docs.ultralytics.com/tasks/obb/) for full details.

# %%
# Load YOLO26n-obb, train it on DOTA8 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n-obb.pt')  # load a pretrained YOLO OBB model
model.train(data='dota8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/boats.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Pip install from source
# !uv pip install git+https://github.com/ultralytics/ultralytics@main

# %%
# Git clone and run tests on 'main' branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# !uv pip install -qe ultralytics

# %%
# Run tests (Git clone only)
# !pytest ultralytics/tests

# %%
# Validate multiple models
for x in 'nsmlx':
  # !yolo val model=yolo26{x}.pt data=coco.yaml
